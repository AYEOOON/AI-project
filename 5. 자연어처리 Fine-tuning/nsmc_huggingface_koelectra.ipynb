# %% [markdown]
# <a href="https://colab.research.google.com/github/AYEOOON/AI-project/blob/main/5.%20%EC%9E%90%EC%97%B0%EC%96%B4%EC%B2%98%EB%A6%AC%20Fine-tuning/nsmc_huggingface_koelectra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pytorch + HuggingFace
# ## KoElectra Model
# 박장원님의 KoElectra-small 사용<br>
# https://monologg.kr/2020/05/02/koelectra-part1/<br>
# https://github.com/monologg/KoELECTRA
#
# ## Dataset
# 네이버 영화 리뷰 데이터셋<br>
# https://github.com/e9t/nsmc
#
# ## References
# - https://huggingface.co/transformers/training.html
# - https://tutorials.pytorch.kr/beginner/data_loading_tutorial.html
# - https://tutorials.pytorch.kr/beginner/blitz/cifar10_tutorial.html
# - https://wikidocs.net/44249
#
# ## 주의사항
# 꼭 GPU로 해주세요 - 1epoch 당 약 20분 소요

# %%
# HuggingFace transformers 설치 및 NSMC 데이터셋 다운로드
# !pip install transformers
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Out:
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 49.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 54.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0
# --2023-10-10 09:08:52--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893335 (4.7M) [text/plain]
# Saving to: ‘ratings_test.txt’
#
# ratings_test.txt    100%[===================>]   4.67M  --.-KB/s    in 0.06s
#
# 2023-10-10 09:08:53 (84.8 MB/s) - ‘ratings_test.txt’ saved [4893335/4893335]
#
# --2023-10-10 09:08:53--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14628807 (14M) [text/plain]
# Saving to: ‘ratings_train.txt’
#
# ratings_train.txt   100%[===================>]  13.95M  --.-KB/s    in 0.09s
#
# 2023-10-10 09:08:53 (163 MB/s) - ‘ratings_train.txt’ saved [14628807/14628807]

# %%
# !head ratings_train.txt
# !head ratings_test.txt
# Out:
# id	document	label
# 9976970	아 더빙.. 진짜 짜증나네요 목소리	0
# 3819312	흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나	1
# 10265843	너무재밓었다그래서보는것을추천한다	0
# 9045019	교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정	0
# 6483659	사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다	1
# 5403919	막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.	0
# 7797314	원작의 긴장감을 제대로 살려내지못했다.	0
# 9443947	별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네	0
# 7156791	액션이 없는데도 재미 있는 몇안되는 영화	1
# id	document	label
# 6270596	굳 ㅋ	1
# 9274899	GDNTOPCLASSINTHECLUB	0
# 8544678	뭐야 이 평점들은.... 나쁘진 않지만 10점 짜리는 더더욱 아니잖아	0
# 6825595	지루하지는 않은데 완전 막장임... 돈주고 보기에는....	0
# 6723715	3D만 아니었어도 별 다섯 개 줬을텐데.. 왜 3D로 나와서 제 심기를 불편하게 하죠??	0
# 7898805	음악이 주가 된, 최고의 음악영화	1
# 6315043	진정한 쓰레기	0
# 6097171	마치 미국애니에서 튀어나온듯한 창의력없는 로봇디자인부터가,고개를 젖게한다	0
# 8932678	갈수록 개판되가는 중국영화 유치하고 내용없음 폼잡다 끝남 말도안되는 무기에 유치한cg남무 아 그립다 동사서독같은 영화가 이건 3류아류작이다	0

# %%
import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from tqdm.notebook import tqdm

# %%
# GPU 사용
device = torch.device("cuda")

# %% [markdown]
# # Dataset 만들어서 불러오기

# %%
class NSMCDataset(Dataset):

  def __init__(self, csv_file):
    # 일부 값중에 NaN이 있음...
    self.dataset = pd.read_csv(csv_file, sep='\t').dropna(axis=0)
    # 중복제거
    self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-small-v2-discriminator")

    print(self.dataset.describe())

  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    y = row[1]

    inputs = self.tokenizer(
        text,
        return_tensors='pt',
        truncation=True,
        max_length=256,
        pad_to_max_length=True,
        add_special_tokens=True
        )

    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
train_dataset = NSMCDataset("ratings_train.txt")
test_dataset = NSMCDataset("ratings_test.txt")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/486 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/255k [00:00<?, ?B/s]
#                  id          label
# count  1.461820e+05  146182.000000
# mean   6.779186e+06       0.498283
# std    2.919223e+06       0.499999
# min    3.300000e+01       0.000000
# 25%    4.814832e+06       0.000000
# 50%    7.581160e+06       0.000000
# 75%    9.274760e+06       1.000000
# max    1.027815e+07       1.000000
#                  id         label
# count  4.915700e+04  49157.000000
# mean   6.752945e+06      0.502695
# std    2.937158e+06      0.499998
# min    6.010000e+02      0.000000
# 25%    4.777143e+06      0.000000
# 50%    7.565415e+06      1.000000
# 75%    9.260204e+06      1.000000
# max    1.027809e+07      1.000000

# %% [markdown]
# # Create Model

# %%
model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator").to(device)

# 한번 실행해보기
# text, attention_mask, y = train_dataset[0]
# model(text.unsqueeze(0).to(device), attention_mask=attention_mask.unsqueeze(0).to(device))
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/452M [00:00<?, ?B/s]
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# model.load_state_dict(torch.load("model.pt"))

# %%
# 모델 레이어 보기
model
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(35000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# # Learn

# %%
epochs = 2
batch_size = 16

# %%
optimizer = AdamW(model.parameters(), lr=5e-6)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
losses = []
accuracies = []

for i in range(epochs):
  total_loss = 0.0
  correct = 0
  total = 0
  batches = 0

  model.train()

  for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
    optimizer.zero_grad()
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    loss = F.cross_entropy(y_pred, y_batch)
    loss.backward()
    optimizer.step()

    total_loss += loss.item()

    _, predicted = torch.max(y_pred, 1)
    correct += (predicted == y_batch).sum()
    total += len(y_batch)

    batches += 1
    if batches % 100 == 0:
      print("Batch Loss:", total_loss, "Accuracy:", correct.float() / total)

  losses.append(total_loss)
  accuracies.append(correct.float() / total)
  print("Train Loss:", total_loss, "Accuracy:", correct.float() / total)
# Out:
#   0%|          | 0/9137 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2622: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2622: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Batch Loss: 68.99891781806946 Accuracy: tensor(0.5412, device='cuda:0')
# Batch Loss: 137.76269167661667 Accuracy: tensor(0.5419, device='cuda:0')
# Batch Loss: 205.84427690505981 Accuracy: tensor(0.5506, device='cuda:0')
# Batch Loss: 273.4399467110634 Accuracy: tensor(0.5608, device='cuda:0')
# Batch Loss: 339.3386821746826 Accuracy: tensor(0.5724, device='cuda:0')
# Batch Loss: 404.96190655231476 Accuracy: tensor(0.5792, device='cuda:0')
# Batch Loss: 467.5299069881439 Accuracy: tensor(0.5900, device='cuda:0')
# Batch Loss: 528.9761313796043 Accuracy: tensor(0.5989, device='cuda:0')
# Batch Loss: 588.776546984911 Accuracy: tensor(0.6092, device='cuda:0')
# Batch Loss: 649.9309974610806 Accuracy: tensor(0.6148, device='cuda:0')
# Batch Loss: 708.0534428954124 Accuracy: tensor(0.6224, device='cuda:0')
# Batch Loss: 765.289249420166 Accuracy: tensor(0.6291, device='cuda:0')
# Batch Loss: 822.2202504277229 Accuracy: tensor(0.6347, device='cuda:0')
# Batch Loss: 879.9733368456364 Accuracy: tensor(0.6392, device='cuda:0')
# Batch Loss: 935.753648430109 Accuracy: tensor(0.6445, device='cuda:0')
# Batch Loss: 991.1958698034286 Accuracy: tensor(0.6489, device='cuda:0')
# Batch Loss: 1047.2896198481321 Accuracy: tensor(0.6532, device='cuda:0')
# Batch Loss: 1100.8943781852722 Accuracy: tensor(0.6577, device='cuda:0')
# Batch Loss: 1156.1980368196964 Accuracy: tensor(0.6611, device='cuda:0')
# Batch Loss: 1209.3086803555489 Accuracy: tensor(0.6645, device='cuda:0')
# Batch Loss: 1262.8414748311043 Accuracy: tensor(0.6673, device='cuda:0')
# Batch Loss: 1318.5606294870377 Accuracy: tensor(0.6696, device='cuda:0')
# Batch Loss: 1371.6668883562088 Accuracy: tensor(0.6719, device='cuda:0')
# Batch Loss: 1425.7088586986065 Accuracy: tensor(0.6745, device='cuda:0')
# Batch Loss: 1476.9778437912464 Accuracy: tensor(0.6775, device='cuda:0')
# Batch Loss: 1529.4904990196228 Accuracy: tensor(0.6800, device='cuda:0')
# Batch Loss: 1581.1983473598957 Accuracy: tensor(0.6820, device='cuda:0')
# Batch Loss: 1633.2096663564444 Accuracy: tensor(0.6844, device='cuda:0')
# Batch Loss: 1683.9674661904573 Accuracy: tensor(0.6867, device='cuda:0')
# Batch Loss: 1735.095052972436 Accuracy: tensor(0.6890, device='cuda:0')
# Batch Loss: 1786.9115025401115 Accuracy: tensor(0.6910, device='cuda:0')
# Batch Loss: 1837.9443889260292 Accuracy: tensor(0.6927, device='cuda:0')
# Batch Loss: 1888.5739687383175 Accuracy: tensor(0.6946, device='cuda:0')
# Batch Loss: 1939.6755272001028 Accuracy: tensor(0.6958, device='cuda:0')
# Batch Loss: 1989.9229560643435 Accuracy: tensor(0.6973, device='cuda:0')
# Batch Loss: 2039.2398467510939 Accuracy: tensor(0.6992, device='cuda:0')
# Batch Loss: 2088.3373983353376 Accuracy: tensor(0.7010, device='cuda:0')
# Batch Loss: 2137.6066235154867 Accuracy: tensor(0.7025, device='cuda:0')
# Batch Loss: 2185.6773443073034 Accuracy: tensor(0.7041, device='cuda:0')
# Batch Loss: 2235.483622789383 Accuracy: tensor(0.7054, device='cuda:0')
# Batch Loss: 2283.9539649039507 Accuracy: tensor(0.7069, device='cuda:0')
# Batch Loss: 2332.1698651760817 Accuracy: tensor(0.7083, device='cuda:0')
# Batch Loss: 2380.053996503353 Accuracy: tensor(0.7094, device='cuda:0')
# Batch Loss: 2428.2023411244154 Accuracy: tensor(0.7106, device='cuda:0')
# Batch Loss: 2475.3395842164755 Accuracy: tensor(0.7118, device='cuda:0')
# Batch Loss: 2524.277699023485 Accuracy: tensor(0.7131, device='cuda:0')
# Batch Loss: 2571.8463177084923 Accuracy: tensor(0.7143, device='cuda:0')
# Batch Loss: 2619.5993845760822 Accuracy: tensor(0.7155, device='cuda:0')
# Batch Loss: 2662.358174458146 Accuracy: tensor(0.7171, device='cuda:0')
# Batch Loss: 2706.824311673641 Accuracy: tensor(0.7186, device='cuda:0')
# Batch Loss: 2754.4376553446054 Accuracy: tensor(0.7196, device='cuda:0')
# Batch Loss: 2801.8882438093424 Accuracy: tensor(0.7204, device='cuda:0')
# Batch Loss: 2846.597997903824 Accuracy: tensor(0.7214, device='cuda:0')
# Batch Loss: 2891.4290745705366 Accuracy: tensor(0.7227, device='cuda:0')
# Batch Loss: 2935.156612113118 Accuracy: tensor(0.7238, device='cuda:0')
# Batch Loss: 2981.6039914786816 Accuracy: tensor(0.7247, device='cuda:0')
# Batch Loss: 3026.1828164607286 Accuracy: tensor(0.7259, device='cuda:0')
# Batch Loss: 3069.7693439275026 Accuracy: tensor(0.7270, device='cuda:0')
# Batch Loss: 3115.063945174217 Accuracy: tensor(0.7279, device='cuda:0')
# Batch Loss: 3160.279322743416 Accuracy: tensor(0.7287, device='cuda:0')
# Batch Loss: 3204.7782879918814 Accuracy: tensor(0.7294, device='cuda:0')
# Batch Loss: 3250.6211502850056 Accuracy: tensor(0.7301, device='cuda:0')
# Batch Loss: 3293.4349259138107 Accuracy: tensor(0.7312, device='cuda:0')
# Batch Loss: 3338.506406262517 Accuracy: tensor(0.7318, device='cuda:0')
# Batch Loss: 3383.702726587653 Accuracy: tensor(0.7327, device='cuda:0')
# Batch Loss: 3426.0063662678003 Accuracy: tensor(0.7338, device='cuda:0')
# Batch Loss: 3472.266550719738 Accuracy: tensor(0.7344, device='cuda:0')
# Batch Loss: 3514.322008050978 Accuracy: tensor(0.7354, device='cuda:0')
# Batch Loss: 3557.487898476422 Accuracy: tensor(0.7363, device='cuda:0')
# Batch Loss: 3598.9476502612233 Accuracy: tensor(0.7373, device='cuda:0')
# Batch Loss: 3642.106365405023 Accuracy: tensor(0.7382, device='cuda:0')
# Batch Loss: 3685.0499406531453 Accuracy: tensor(0.7390, device='cuda:0')
# Batch Loss: 3728.1443794593215 Accuracy: tensor(0.7397, device='cuda:0')
# Batch Loss: 3771.5511676594615 Accuracy: tensor(0.7404, device='cuda:0')
# Batch Loss: 3814.4621824398637 Accuracy: tensor(0.7412, device='cuda:0')
# Batch Loss: 3858.314700804651 Accuracy: tensor(0.7418, device='cuda:0')
# Batch Loss: 3900.9444003477693 Accuracy: tensor(0.7426, device='cuda:0')
# Batch Loss: 3943.561969138682 Accuracy: tensor(0.7433, device='cuda:0')
# Batch Loss: 3985.550455711782 Accuracy: tensor(0.7440, device='cuda:0')
# Batch Loss: 4028.7975841090083 Accuracy: tensor(0.7448, device='cuda:0')
# Batch Loss: 4069.451663710177 Accuracy: tensor(0.7457, device='cuda:0')
# Batch Loss: 4110.980930142105 Accuracy: tensor(0.7463, device='cuda:0')
# Batch Loss: 4154.338253699243 Accuracy: tensor(0.7470, device='cuda:0')
# Batch Loss: 4196.021850146353 Accuracy: tensor(0.7478, device='cuda:0')
# Batch Loss: 4238.950363703072 Accuracy: tensor(0.7484, device='cuda:0')
# Batch Loss: 4280.369398616254 Accuracy: tensor(0.7490, device='cuda:0')
# Batch Loss: 4322.004070736468 Accuracy: tensor(0.7496, device='cuda:0')
# Batch Loss: 4364.30851034075 Accuracy: tensor(0.7501, device='cuda:0')
# Batch Loss: 4409.790989808738 Accuracy: tensor(0.7506, device='cuda:0')
# Batch Loss: 4452.101111479104 Accuracy: tensor(0.7513, device='cuda:0')
# Batch Loss: 4491.924980409443 Accuracy: tensor(0.7520, device='cuda:0')
# Train Loss: 4507.075959853828 Accuracy: tensor(0.7522, device='cuda:0')
#   0%|          | 0/9137 [00:00<?, ?it/s]
# Batch Loss: 40.83405967056751 Accuracy: tensor(0.8056, device='cuda:0')
# Batch Loss: 78.62344872951508 Accuracy: tensor(0.8237, device='cuda:0')
# Batch Loss: 118.69133545458317 Accuracy: tensor(0.8167, device='cuda:0')
# Batch Loss: 158.5477038025856 Accuracy: tensor(0.8161, device='cuda:0')
# Batch Loss: 194.34220877289772 Accuracy: tensor(0.8216, device='cuda:0')
# Batch Loss: 234.35243806988 Accuracy: tensor(0.8201, device='cuda:0')
# Batch Loss: 275.2935564145446 Accuracy: tensor(0.8197, device='cuda:0')
# Batch Loss: 315.8556741848588 Accuracy: tensor(0.8192, device='cuda:0')
# Batch Loss: 356.0740299895406 Accuracy: tensor(0.8185, device='cuda:0')
# Batch Loss: 395.0013511925936 Accuracy: tensor(0.8185, device='cuda:0')
# Batch Loss: 435.00902074575424 Accuracy: tensor(0.8181, device='cuda:0')
# Batch Loss: 475.6650054603815 Accuracy: tensor(0.8171, device='cuda:0')
# Batch Loss: 514.6088177412748 Accuracy: tensor(0.8174, device='cuda:0')
# Batch Loss: 552.4963185191154 Accuracy: tensor(0.8182, device='cuda:0')
# Batch Loss: 593.3496601581573 Accuracy: tensor(0.8182, device='cuda:0')
# Batch Loss: 629.2730208933353 Accuracy: tensor(0.8188, device='cuda:0')
# Batch Loss: 670.4345305040479 Accuracy: tensor(0.8185, device='cuda:0')
# Batch Loss: 709.5291499421 Accuracy: tensor(0.8186, device='cuda:0')
# Batch Loss: 748.4757786169648 Accuracy: tensor(0.8184, device='cuda:0')
# Batch Loss: 786.5483279302716 Accuracy: tensor(0.8192, device='cuda:0')
# Batch Loss: 826.6169821098447 Accuracy: tensor(0.8190, device='cuda:0')
# Batch Loss: 865.9337148442864 Accuracy: tensor(0.8188, device='cuda:0')
# Batch Loss: 901.5127505511045 Accuracy: tensor(0.8199, device='cuda:0')
# Batch Loss: 938.6897566467524 Accuracy: tensor(0.8202, device='cuda:0')
# Batch Loss: 977.9743155241013 Accuracy: tensor(0.8201, device='cuda:0')
# Batch Loss: 1018.2204795926809 Accuracy: tensor(0.8204, device='cuda:0')
# Batch Loss: 1056.7310262322426 Accuracy: tensor(0.8206, device='cuda:0')
# Batch Loss: 1096.2953386306763 Accuracy: tensor(0.8204, device='cuda:0')
# Batch Loss: 1135.9808883219957 Accuracy: tensor(0.8203, device='cuda:0')
# Batch Loss: 1173.6179001703858 Accuracy: tensor(0.8205, device='cuda:0')
# Batch Loss: 1211.1994632333517 Accuracy: tensor(0.8208, device='cuda:0')
# Batch Loss: 1248.323744520545 Accuracy: tensor(0.8213, device='cuda:0')
# Batch Loss: 1285.8400949686766 Accuracy: tensor(0.8217, device='cuda:0')
# Batch Loss: 1321.6902981102467 Accuracy: tensor(0.8222, device='cuda:0')
# Batch Loss: 1361.0557092130184 Accuracy: tensor(0.8221, device='cuda:0')
# Batch Loss: 1400.6296368837357 Accuracy: tensor(0.8218, device='cuda:0')
# Batch Loss: 1439.04575163126 Accuracy: tensor(0.8219, device='cuda:0')
# Batch Loss: 1475.5872430354357 Accuracy: tensor(0.8220, device='cuda:0')
# Batch Loss: 1513.370113030076 Accuracy: tensor(0.8224, device='cuda:0')
# Batch Loss: 1553.1118775755167 Accuracy: tensor(0.8222, device='cuda:0')
# Batch Loss: 1592.3027673363686 Accuracy: tensor(0.8223, device='cuda:0')
# Batch Loss: 1630.0105309784412 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 1667.3908188939095 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 1707.0693514198065 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 1745.625204026699 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 1782.5202767699957 Accuracy: tensor(0.8230, device='cuda:0')
# Batch Loss: 1819.084606833756 Accuracy: tensor(0.8231, device='cuda:0')
# Batch Loss: 1857.3276021108031 Accuracy: tensor(0.8231, device='cuda:0')
# Batch Loss: 1896.2735558077693 Accuracy: tensor(0.8230, device='cuda:0')
# Batch Loss: 1934.7493032440543 Accuracy: tensor(0.8228, device='cuda:0')
# Batch Loss: 1974.2512773945928 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 2010.9334772601724 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 2047.8278759792447 Accuracy: tensor(0.8229, device='cuda:0')
# Batch Loss: 2083.1176099553704 Accuracy: tensor(0.8233, device='cuda:0')
# Batch Loss: 2120.4660528339446 Accuracy: tensor(0.8234, device='cuda:0')
# Batch Loss: 2156.998594943434 Accuracy: tensor(0.8236, device='cuda:0')
# Batch Loss: 2193.690079923719 Accuracy: tensor(0.8237, device='cuda:0')
# Batch Loss: 2230.5539824180305 Accuracy: tensor(0.8238, device='cuda:0')
# Batch Loss: 2268.2999664209783 Accuracy: tensor(0.8239, device='cuda:0')
# Batch Loss: 2308.0270238108933 Accuracy: tensor(0.8238, device='cuda:0')
# Batch Loss: 2344.189322691411 Accuracy: tensor(0.8240, device='cuda:0')
# Batch Loss: 2380.360534477979 Accuracy: tensor(0.8243, device='cuda:0')
# Batch Loss: 2419.9954298473895 Accuracy: tensor(0.8242, device='cuda:0')
# Batch Loss: 2456.479228179902 Accuracy: tensor(0.8245, device='cuda:0')
# Batch Loss: 2491.3088516183197 Accuracy: tensor(0.8248, device='cuda:0')
# Batch Loss: 2527.738280225545 Accuracy: tensor(0.8250, device='cuda:0')
# Batch Loss: 2565.618701774627 Accuracy: tensor(0.8248, device='cuda:0')
# Batch Loss: 2602.4950006492436 Accuracy: tensor(0.8249, device='cuda:0')
# Batch Loss: 2638.7473029233515 Accuracy: tensor(0.8249, device='cuda:0')
# Batch Loss: 2676.0005601607263 Accuracy: tensor(0.8250, device='cuda:0')
# Batch Loss: 2713.7923986576498 Accuracy: tensor(0.8250, device='cuda:0')
# Batch Loss: 2749.7186118252575 Accuracy: tensor(0.8251, device='cuda:0')
# Batch Loss: 2786.3825260959566 Accuracy: tensor(0.8252, device='cuda:0')
# Batch Loss: 2824.2607432715595 Accuracy: tensor(0.8253, device='cuda:0')
# Batch Loss: 2862.3119605518878 Accuracy: tensor(0.8253, device='cuda:0')
# Batch Loss: 2897.259687270969 Accuracy: tensor(0.8256, device='cuda:0')
# Batch Loss: 2934.467265751213 Accuracy: tensor(0.8259, device='cuda:0')
# Batch Loss: 2973.5267910920084 Accuracy: tensor(0.8258, device='cuda:0')
# Batch Loss: 3009.5588041730225 Accuracy: tensor(0.8259, device='cuda:0')
# Batch Loss: 3050.086053777486 Accuracy: tensor(0.8258, device='cuda:0')
# Batch Loss: 3087.4757505096495 Accuracy: tensor(0.8259, device='cuda:0')
# Batch Loss: 3125.088793102652 Accuracy: tensor(0.8258, device='cuda:0')
# Batch Loss: 3161.2210993506014 Accuracy: tensor(0.8259, device='cuda:0')
# Batch Loss: 3200.83162080124 Accuracy: tensor(0.8258, device='cuda:0')
# Batch Loss: 3240.5924681164324 Accuracy: tensor(0.8257, device='cuda:0')
# Batch Loss: 3279.2836128361523 Accuracy: tensor(0.8257, device='cuda:0')
# Batch Loss: 3315.382896248251 Accuracy: tensor(0.8258, device='cuda:0')
# Batch Loss: 3354.834724057466 Accuracy: tensor(0.8258, device='cuda:0')
# Batch Loss: 3390.6779907271266 Accuracy: tensor(0.8260, device='cuda:0')
# Batch Loss: 3428.340120509267 Accuracy: tensor(0.8260, device='cuda:0')
# Batch Loss: 3466.35007314384 Accuracy: tensor(0.8260, device='cuda:0')
# Train Loss: 3479.6158393472433 Accuracy: tensor(0.8260, device='cuda:0')

# %%
losses, accuracies
# Out:
# ([4507.075959853828, 3479.6158393472433],
#  [tensor(0.7522, device='cuda:0'), tensor(0.8260, device='cuda:0')])

# %% [markdown]
# 테스트 데이터셋 정확도 확인하기

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
  y_batch = y_batch.to(device)
  y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
  _, predicted = torch.max(y_pred, 1)
  test_correct += (predicted == y_batch).sum()
  test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)
# Out:
#   0%|          | 0/3073 [00:00<?, ?it/s]
# Accuracy: tensor(0.8348, device='cuda:0')

# %%
# 모델 저장하기
torch.save(model.state_dict(), "model.pt")
